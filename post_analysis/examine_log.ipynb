# %%
from pathlib import Path
import json
import pandas as pd
import os

# Path to the args_logs.json file in your local run. the project_name and run_timestampe need to be changed
json_path = Path("../Experiment_RUNS_BY_Projects/whatever/CHECKPOINTS/run_timestamp_2025-07-14_19-52-58/args_logs.json")

# Load JSON contents
with open(json_path, 'r') as f:
    args_data = json.load(f)

# Display the raw dictionary
print("Loaded args:")
for k, v in args_data.items():
    print(f"{k:30} : {v}")

# Optional: Convert to DataFrame for nicer viewing
pd.DataFrame.from_dict(args_data, orient='index', columns=['value'])
# Out:
# Loaded args:
# project_name                   : whatever
# my_data_ready_dir              : i_did_something
# seed                           : 666
# training_inference_mode        : training
# debug_mode                     : False
# train_mode                     : classic
# loss_func                      : cross_entropy
# lr                             : 99
# experiment_dir                 : Experiment_RUNS_BY_Projects
# experiment_dir_by_project      : Experiment_RUNS_BY_Projects/whatever
# data_path                      : DATA
# data_path_by_choice            : DATA/i_did_something
# checkpoint_dir                 : Experiment_RUNS_BY_Projects/whatever/CHECKPOINTS/run_timestamp_2025-07-14_19-52-58
#                                                                        value
# project_name                                                        whatever
# my_data_ready_dir                                            i_did_something
# ...
